# %%
import pandas as pd
# 数据去重清洗
inputfile='G:\\XX\\Data\\brands\\meidi.txt'
outputfile='G:\\XX\\Data\\brands\\meidi_process_1.txt'
data=pd.read_csv(inputfile, encoding='utf-8', header=None)
l1=len(data)
data=pd.DataFrame(data[0].unique())
l2=len(data)
data.to_csv(outputfile, index=False, header=False, encoding='utf-8')
print(u'删除了%s条评论' %(l1-l2))
# Out:
# 删除了2352条评论

# %%
import codecs
# 删除评论的前缀中相同的词
inputfile = 'G:\\XX\\Data\\brands\\meidi_process_1.txt' #评论文件
outputfile = 'G:\\XX\\Data\\brands\\meidi_process_2.txt' #评论处理后保存路径
f = codecs.open(inputfile ,'r','utf-8')
f1=codecs.open(outputfile,'w','utf-8')
fileList = f.readlines()
f.close()
for A_string in fileList:
    temp1= A_string.strip('\n')       #去掉每行最后的换行符'\n'
    temp2 = temp1.lstrip('\ufeff')
    temp3= temp2.strip('\r')
    char_list=list( temp3)
    list1=['']
    list2=['']
    del1=[]
    flag=['']
    i=0
    while(i<len(char_list)):
        if (char_list[i]==list1[0]):
            if (list2==['']):
                list2[0]=char_list[i]
            else:
                if (list1==list2):
                    t=len(list1)
                    m=0
                    while(m<t):
                        del1.append( i-m-1)
                        m=m+1
                    list2=['']
                    list2[0]=char_list[i]
                else:
                    list1=['']
                    list2=['']
                    flag=['']
                    list1[0]=char_list[i]
                    flag[0]=i
        else:
            if (list1==list2)and(list1!=[''])and(list2!=['']):
                if len(list1)>=2:
                    t=len(list1)
                    m=0
                    while(m<t):
                        del1.append( i-m-1)
                        m=m+1
                    list1=['']
                    list2=['']
                    list1[0]=char_list[i]
                    flag[0]=i
            else:
                if(list2==['']):
                    if(list1==['']):
                        list1[0]=char_list[i]
                        flag[0]=i
                    else:
                        list1.append(char_list[i])
                        flag.append(i)
                else:
                    list2.append(char_list[i])
        i=i+1
        if(i==len(char_list)):
            if(list1==list2):
                    t=len(list1)
                    m=0
                    while(m<t):
                        del1.append( i-m-1)
                        m=m+1
                    m=0
                    while(m<t):
                        del1.append(flag[m])
                        m=m+1
    a=sorted(del1)
    t=len(a)-1
    while (t>=0):
        #print(char_list[a[t]])
        del char_list[a[t]]
        t=t-1
    str1 = "".join(char_list)
    str2=str1.strip() #删除两边空格
    f1.writelines(str2+'\r\n')
f1.close()

# %%
import pandas as pd
# 将得到的每个句子进行反转
inputfile = 'G:\\XX\\Data\\brands\\meidi_process_2.txt' #评论文件
outputfile = 'G:\\XX\\Data\\brands\\meidi_process_3.txt' #句子倒序
data = pd.read_csv(inputfile, encoding = 'utf-8', header = None)
data = pd.DataFrame(data[0])
with open(outputfile, 'w' ,encoding='utf-8') as f:
    file_obj = open(inputfile,encoding='utf8')
    all_lines = file_obj.readlines()
    for line in all_lines:
        f.write(line[::-1])
    file_obj.close()

# %%
import codecs
# 反转后，删除评论的前缀中相同的词
inputfile = 'G:\\XX\\Data\\brands\\meidi_process_3.txt' #评论文件
outputfile = 'G:\\XX\\Data\\brands\\meidi_process_4.txt' #评论处理后保存路径
f = codecs.open(inputfile ,'r','utf-8')
f1=codecs.open(outputfile,'w','utf-8')
fileList = f.readlines()
f.close()
for A_string in fileList:
    temp1= A_string.strip('\n')       #去掉每行最后的换行符'\n'
    temp2 = temp1.lstrip('\ufeff')
    temp3= temp2.strip('\r')
    char_list=list( temp3)
    list1=['']
    list2=['']
    del1=[]
    flag=['']
    i=0
    while(i<len(char_list)):
        if (char_list[i]==list1[0]):
            if (list2==['']):
                list2[0]=char_list[i]
            else:
                if (list1==list2):
                    t=len(list1)
                    m=0
                    while(m<t):
                        del1.append( i-m-1)
                        m=m+1
                    list2=['']
                    list2[0]=char_list[i]
                else:
                    list1=['']
                    list2=['']
                    flag=['']
                    list1[0]=char_list[i]
                    flag[0]=i
        else:
            if (list1==list2)and(list1!=[''])and(list2!=['']):
                if len(list1)>=2:
                    t=len(list1)
                    m=0
                    while(m<t):
                        del1.append( i-m-1)
                        m=m+1
                    list1=['']
                    list2=['']
                    list1[0]=char_list[i]
                    flag[0]=i
            else:
                if(list2==['']):
                    if(list1==['']):
                        list1[0]=char_list[i]
                        flag[0]=i
                    else:
                        list1.append(char_list[i])
                        flag.append(i)
                else:
                    list2.append(char_list[i])
        i=i+1
        if(i==len(char_list)):
            if(list1==list2):
                    t=len(list1)
                    m=0
                    while(m<t):
                        del1.append( i-m-1)
                        m=m+1
                    m=0
                    while(m<t):
                        del1.append(flag[m])
                        m=m+1
    a=sorted(del1)
    t=len(a)-1
    while (t>=0):
        #print(char_list[a[t]])
        del char_list[a[t]]
        t=t-1
    str1 = "".join(char_list)
    str2=str1.strip() #删除两边空格
    f1.writelines(str2+'\r\n')
f1.close()

# %%
import pandas as pd
# 一次反转后，将得到的每个句子再进行反转
inputfile = 'G:\\XX\\Data\\brands\\meidi_process_4.txt' #评论文件
outputfile = 'G:\\XX\\Data\\brands\\meidi_process_5.txt' #句子倒序
data = pd.read_csv(inputfile, encoding = 'utf-8', header = None)
data = pd.DataFrame(data[0])
with open(outputfile, 'w' ,encoding='utf-8') as f:
    file_obj = open(inputfile,encoding='utf8')
    all_lines = file_obj.readlines()
    for line in all_lines:
        f.write(line[::-1])
    file_obj.close()

# %%
import pandas as pd
# 删除评论中小于4个字符的评论
inputfile = 'G:\\XX\\Data\\brands\\meidi_process_5.txt'
outputfile = 'G:\\XX\\Data\\brands\\meidi_process_end.txt' 
data = pd.read_csv(inputfile, encoding = 'utf-8', header = None)
data = pd.DataFrame(data[0])
with open(outputfile, 'w' ,encoding='utf-8') as f:
    file_obj = open(inputfile,encoding='utf8')
    all_lines = file_obj.readlines()
    for line in all_lines:
        if(len(line)>4):
            f.write(line)
    file_obj.close()

# %%
# 分词
import jieba
inputfile = 'G:\\XX\\Data\\brands\\AO_process_end.txt'
outputfile = 'G:\\XX\\Data\\brands\\AO_process_cut1.txt'
data = pd.read_csv(inputfile, encoding = 'utf-8', header = None)
jieba.load_userdict('G:\\XX\\Data\\dicts\\Dict.txt')
mycut = lambda s: ' '.join(pseg.cut(s)) #自定义简单分词函数
data = data[0].apply(mycut) #通过“广播”形式分词，加快速度。
data.to_csv(outputfile, index = False, header = False, encoding = 'utf-8') #保存结果
# Out:
# <function <lambda> at 0x00000000147CF598>

# %%
# 去停用词
stoplist = 'G:\\XX\\Data\\dicts\\stoplist.txt'
inputfile = 'G:\\XX\\Data\\brands\\AO_process_cut1.txt'
outputfile = 'G:\\XX\\Data\\brands\\AO_process_cut2.txt'
data = pd.read_csv(inputfile, encoding = 'utf-8', header = None)
stop = pd.read_csv(stoplist, encoding = 'utf-8', header = None, sep = 'tipdm',engine='python')  
stop = [' ', ''] + list(stop[0])
data[1] = data[0].apply(lambda s: s.split(' ')) #定义一个分割函数，然后用apply广播  
data[2] = data[1].apply(lambda x: [i for i in x if i not in stop]) #逐词判断是否停用词
data[2].to_csv(outputfile, index = False, header = False, encoding = 'utf-8')

# %%
import jieba
import jieba.posseg
import jieba.analyse
# 实体词抽取
inputfile = 'G:\\XX\\Data\\brands\\wanjiale_process_end.txt'
outputfile = 'G:\\XX\\Data\\brands\\wanjiale_process_endcut.txt'
data = open(inputfile, encoding = 'utf-8').readlines()
output = open(outputfile, 'w', encoding='UTF-8')
jieba.load_userdict('G:\\XX\\Data\\dicts\\Dict.txt')
for line in data:
    tags = jieba.analyse.extract_tags(line, withWeight=False, topK=1000, allowPOS=('n', 'v', 'a', 'ad', 'an', 'd'))
    output.write(','.join(tags))
    output.write('\n')
output.close()

# %%
from collections import defaultdict
# 分词列表转换为字典
def list_to_dict(word_str):
    """将分词后的列表转为字典，key为单词，value为单词在列表中的索引，索引相当于词语在文档中出现的位置"""
    data = {}
    word_list = word_str.strip().split(',')
    for x in range(0, len(word_list)):
        data[word_list[x]] = x
    return data

# %%
def classify_word(word_dict):
    # 读取情感字典文件
    sen_file = open('G:\\XX\\Data\\dicts\\sentiment.txt', 'r', encoding='utf-8')
    # 获取字典文件内容
    sen_list = sen_file.readlines()
    # 创建情感字典
    sen_dict = defaultdict()
    # 读取字典文件每一行内容，将其转换为字典对象，key为情感词，value为对应的分值
    for s in sen_list:
        # 每一行内容根据空格分割，索引0是情感词，索引01是情感分值
        sen_dict[s.split(' ')[0]] = s.split(' ')[1]
 
    # 分类结果，词语的index作为key,词语的分值作为value，否定词分值设为-1
    sen_word = dict()
 
    # 分类
    for word in word_dict.keys():
        if word in sen_dict.keys():
            # 找出分词结果中在情感字典中的词
            sen_word[word_dict[word]] = sen_dict[word]
    sen_file.close()
    return sen_word

# %%
def score_sentiment(sen_word, line):
    """计算得分"""
    # 权重初始化为1
    W = 1
    score = 0
    # 情感词下标初始化
    sentiment_index = -1
    # 情感词的位置下标集合
    sentiment_index_list = list(sen_word.keys())
    # 遍历分词结果(遍历分词结果是为了定位两个情感词之间的程度副词和否定词)
    for i in range(0, len(line)):
        # 如果是情感词（根据下标是否在情感词分类结果中判断）
        if i in sen_word.keys():
            # 权重*情感词得分
            score += W * float(sen_word[i])
            # 情感词下标加1，获取下一个情感词的位置
            sentiment_index += 1 
        # 定位到下一个情感词
        if sentiment_index < len(sentiment_index_list) - 1:
            i = sentiment_index_list[sentiment_index + 1]
    return score

# %%
if __name__ == '__main__':
    inputfile = 'G:\\XX\\Data\\brands\\haier_process_endcut.txt'
    outputfile1 = 'G:\\XX\\Data\\brands\\haier_process_pos.txt'
    outputfile2 = 'G:\\XX\\Data\\brands\\haier_process_neg.txt'
    data = open(inputfile, encoding = 'utf-8').readlines()
    output1 = open(outputfile1, 'w', encoding='UTF-8')
    output2 = open(outputfile2, 'w', encoding='UTF-8')
    for line in data:
        sen_word = classify_word(list_to_dict(line))
        score = score_sentiment(sen_word, line)
#         print(score)
        if(score>0):
            output1.write(line)
        elif(score<0):
            output2.write(line)
    output1.close()
    output2.close()

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.externals import joblib
from sklearn.decomposition import LatentDirichletAllocation
pos=open('G:\\XX\\Data\\brands\\haier_process_pos.txt', encoding='UTF-8').readlines()
neg=open('G:\\XX\\Data\\brands\\haier_process_neg.txt', encoding='UTF-8').readlines()
#构建词汇统计向量并保存，仅运行首次
# tf_vectorizer = CountVectorizer(max_df=0.9, min_df=2, max_features=2500, stop_words=None)
# tf = tf_vectorizer.fit_transform(pos)
# joblib.dump(tf_vectorizer,tf_ModelPath)
# #得到存储的tf_vectorizer,节省预处理时间
# tf_vectorizer = joblib.load(tf_ModelPath)
# tf = tf_vectorizer.fit_transform(pos)

vect = TfidfVectorizer(max_features=2500, min_df=2, max_df=0.95, stop_words=None)
X = vect.fit_transform(neg)
feature_names=np.array(vect.get_feature_names())
sorted_by_tfidf = np.argsort(X.max(axis=0).toarray().ravel())
#输出TFIDF排序最小的20与最大的20个term
# print(feature_names[sorted_by_tfidf])
# print(feature_names[sorted_by_tfidf[:20]])
# print(feature_names[sorted_by_tfidf[-20:]])

# %%
# 可删失败，LDA模型调参寻优
from sklearn.model_selection import GridSearchCV
parameters = {
    "learning_method": 'batch', 
    "n_topics": range(1,16),
    "doc_topic_prior": [0.1, 0.5, 0.9],
    "topic_word_prior": [0.01, 0.1],
    "max_iter": 1000
}
lda = LatentDirichletAllocation()
model = GridSearchCV(lda, param_grid=parameters)
model.fit(X)
best_params=grid.best_params_
best_score=grid.best_score_
print(best_params)
# sorted(model.cv_results_.keys())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-e79e3d8bba60> in <module>()
#       9 }
#      10 lda = LatentDirichletAllocation()
# ---> 11 model = GridSearchCV(lda, param_grid=parameters)
#      12 model.fit(X)
#      13 best_params=grid.best_params_
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in __init__(self, estimator, param_grid, scoring, fit_params, n_jobs, iid, refit, cv, verbose, pre_dispatch, error_score, return_train_score)
#    1185             return_train_score=return_train_score)
#    1186         self.param_grid = param_grid
# -> 1187         _check_param_grid(param_grid)
#    1188
#    1189     def _run_search(self, evaluate_candidates):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _check_param_grid(param_grid)
# ...

# %%
import pyLDAvis
import pyLDAvis.sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
pos=open('G:\\XX\\Data\\brands\\gelanshi_process_pos.txt', encoding='UTF-8').readlines()
vectorizer = CountVectorizer()
doc_term_matrix = vectorizer.fit_transform(pos)
lda_model = LatentDirichletAllocation(n_components=3, random_state=888)
lda_model.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=3, n_jobs=None, n_topics=None, perp_tol=0.1,
#              random_state=888, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
# %matplotlib notebook
data = pyLDAvis.sklearn.prepare(lda_model, doc_term_matrix, vectorizer)
pyLDAvis.display(data)
pyLDAvis.show(data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# Note: if you're in the IPython notebook, pyLDAvis.show() is not the best command
#       to use. Consider using pyLDAvis.display(), or pyLDAvis.enable_notebook().
#       See more information at http://pyLDAvis.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8889/    [Ctrl-C to exit]
# 127.0.0.1 - - [15/Jan/2020 14:02:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jan/2020 14:02:27] "GET /LDAvis.css HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jan/2020 14:02:27] "GET /d3.js HTTP/1.1" 200 -
# ...

# %%
# import mglearn
from sklearn.decomposition import LatentDirichletAllocation
lda = LatentDirichletAllocation(n_topics=3, max_iter=50, learning_method='batch')
lda.fit(X)
sorting = np.argsort(lda.components_, axis=1)[:, ::-1]
feature_names = np.array(vect.get_feature_names())
# mglearn.tools.print_topics(topics=range(3), feature_names=feature_names, sorting=sorting, topics_per_chunk=5, n_words=10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:314: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)

# %%
def print_top_words(model, feature_names, n_top_words):
    #打印每个主题下权重较高的term
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))
    #打印主题-词语分布矩阵
#         print("#主题-词语分布矩阵: \n" % model.components_)
n_top_words=10
feature_names = vect.get_feature_names()
print_top_words(lda, feature_names, n_top_words)
print(lda.perplexity(X))
# Out:
# Topic #0:
# 没用 不错 发现 缺点 安装 应该 知道 不好 暂时 送货
# Topic #1:
# 安装 就是 麻烦 售后 收费 没有 送货 材料费 安装费 失望
# Topic #2:
# 不够 加热 有点 就是 保温 热水 方便 速度 不好 凑合
# 1390.2030984141834

# %%
# 绘制词云
import matplotlib.pyplot as plt
from wordcloud import WordCloud
pos=open('G:\\XX\\Data\\brands\\haier_process_pos.txt', encoding='UTF-8').read()
neg=open('G:\\XX\\Data\\brands\\haier_process_neg.txt', encoding='UTF-8').read()
wordcloud = WordCloud(
    collocations=False,
    background_color='white',#词云背景图颜色
    font_path=r'G:\XX\Data\fonts\microsoftFonts.ttf',#词云中的字体样式
    width=1000,#词云宽度
    height=800#词云高度
).generate(neg)#根据弹幕生成词云对象
 
plt.imshow(wordcloud)
plt.axis('off') #去掉图片的坐标轴|
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
